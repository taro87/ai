# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:90% !important;}
div.cell.code_cell.rendered{width:100%;}
div.input_prompt{padding:0px;}
div.CodeMirror {font-family:Consolas; font-size:16pt;}
div.text_cell_render.rendered_html{font-size:16pt;}
div.output {font-size:12pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:16pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:16pt;padding:5px;}
table.dataframe{font-size:16px;}
</style>
"""))
# Out:
# <style>
# div.container{width:90% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.input_prompt{padding:0px;}
# div.CodeMirror {font-family:Consolas; font-size:16pt;}
# div.text_cell_render.rendered_html{font-size:16pt;}
# div.output {font-size:12pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:16pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:16pt;padding:5px;}
# table.dataframe{font-size:16px;}
# </style>

# %%
import numpy as np
from tensorflow.keras.models import Sequential # 모델 객체 생성
from tensorflow.keras.layers import Input, Dense # 모델 layer 쌓을 때 필요
import matplotlib.pyplot as plt

# %%
# data set
x_data = np.array([[0, 0],
                   [0, 1],
                   [1, 0], 
                   [1, 1]])
y_data = np.array([[0], [1], [1], [0]])
# 2. 모델 구성
model = Sequential()
# model.add(Input(shape=2))
model.add(Dense(units=10, # 출력 갯수
               input_dim=2, # input_shape = (2,) # 입력 갯수
               activation='relu')) # 활성화 함수
model.add(Dense(units=20, activation='relu')) # 은닉층에서는 input_shape는 X
model.add(Dense(10, activation='relu'))
model.add(Dense(units=1, activation='sigmoid'))
print(model.summary())
# 3. 모델 학습과정 설정
    # loss : mae(회귀분석), binary_crossentropy(이진분류=로지스틱회귀분석),
        # categorical_crossentropy(다중분류-원핫인코딩을 한 경우)
        # sparde_categorical_crossentropy(다중분류-원핫인코딩을 안 한 경우)
model.compile(loss = 'binary_crossentropy', # 손실함수(loss function)
             optimizer='adam',
             metrics=['binary_accuracy']) # 2진분류
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 10)                30
#
#  dense_5 (Dense)             (None, 20)                220
#
#  dense_6 (Dense)             (None, 10)                210
#
#  dense_7 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 471
# Trainable params: 471
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# 4. 학습
hist = model.fit(x_data, y_data, epochs=300, verbose=2)
# Out:
# Epoch 1/300
# 1/1 - 1s - loss: 0.6842 - binary_accuracy: 0.7500 - 653ms/epoch - 653ms/step
# Epoch 2/300
# 1/1 - 0s - loss: 0.6814 - binary_accuracy: 0.5000 - 2ms/epoch - 2ms/step
# Epoch 3/300
# 1/1 - 0s - loss: 0.6786 - binary_accuracy: 0.7500 - 4ms/epoch - 4ms/step
# Epoch 4/300
# 1/1 - 0s - loss: 0.6758 - binary_accuracy: 0.7500 - 4ms/epoch - 4ms/step
# Epoch 5/300
# 1/1 - 0s - loss: 0.6730 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 6/300
# 1/1 - 0s - loss: 0.6702 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 7/300
# 1/1 - 0s - loss: 0.6677 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 8/300
# 1/1 - 0s - loss: 0.6652 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 9/300
# 1/1 - 0s - loss: 0.6626 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 10/300
# 1/1 - 0s - loss: 0.6601 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 11/300
# 1/1 - 0s - loss: 0.6577 - binary_accuracy: 0.7500 - 4ms/epoch - 4ms/step
# Epoch 12/300
# 1/1 - 0s - loss: 0.6557 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 13/300
# 1/1 - 0s - loss: 0.6536 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 14/300
# 1/1 - 0s - loss: 0.6514 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 15/300
# 1/1 - 0s - loss: 0.6492 - binary_accuracy: 0.7500 - 4ms/epoch - 4ms/step
# Epoch 16/300
# 1/1 - 0s - loss: 0.6471 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 17/300
# 1/1 - 0s - loss: 0.6453 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 18/300
# 1/1 - 0s - loss: 0.6434 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 19/300
# 1/1 - 0s - loss: 0.6414 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 20/300
# 1/1 - 0s - loss: 0.6395 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 21/300
# 1/1 - 0s - loss: 0.6375 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 22/300
# 1/1 - 0s - loss: 0.6355 - binary_accuracy: 0.7500 - 4ms/epoch - 4ms/step
# Epoch 23/300
# 1/1 - 0s - loss: 0.6334 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 24/300
# 1/1 - 0s - loss: 0.6314 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 25/300
# 1/1 - 0s - loss: 0.6293 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 26/300
# 1/1 - 0s - loss: 0.6272 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 27/300
# 1/1 - 0s - loss: 0.6250 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 28/300
# 1/1 - 0s - loss: 0.6230 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 29/300
# 1/1 - 0s - loss: 0.6211 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 30/300
# 1/1 - 0s - loss: 0.6191 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 31/300
# 1/1 - 0s - loss: 0.6171 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 32/300
# 1/1 - 0s - loss: 0.6151 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 33/300
# 1/1 - 0s - loss: 0.6130 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 34/300
# 1/1 - 0s - loss: 0.6110 - binary_accuracy: 0.7500 - 7ms/epoch - 7ms/step
# Epoch 35/300
# 1/1 - 0s - loss: 0.6089 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 36/300
# 1/1 - 0s - loss: 0.6067 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 37/300
# 1/1 - 0s - loss: 0.6046 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 38/300
# 1/1 - 0s - loss: 0.6026 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 39/300
# 1/1 - 0s - loss: 0.6004 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 40/300
# 1/1 - 0s - loss: 0.5984 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 41/300
# 1/1 - 0s - loss: 0.5962 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 42/300
# 1/1 - 0s - loss: 0.5940 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 43/300
# 1/1 - 0s - loss: 0.5919 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 44/300
# 1/1 - 0s - loss: 0.5897 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 45/300
# 1/1 - 0s - loss: 0.5876 - binary_accuracy: 0.7500 - 6ms/epoch - 6ms/step
# Epoch 46/300
# 1/1 - 0s - loss: 0.5854 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 47/300
# 1/1 - 0s - loss: 0.5832 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 48/300
# 1/1 - 0s - loss: 0.5810 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 49/300
# 1/1 - 0s - loss: 0.5788 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 50/300
# 1/1 - 0s - loss: 0.5765 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 51/300
# 1/1 - 0s - loss: 0.5743 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 52/300
# 1/1 - 0s - loss: 0.5721 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 53/300
# 1/1 - 0s - loss: 0.5700 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 54/300
# 1/1 - 0s - loss: 0.5677 - binary_accuracy: 0.7500 - 4ms/epoch - 4ms/step
# Epoch 55/300
# 1/1 - 0s - loss: 0.5657 - binary_accuracy: 0.7500 - 4ms/epoch - 4ms/step
# Epoch 56/300
# 1/1 - 0s - loss: 0.5636 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 57/300
# 1/1 - 0s - loss: 0.5614 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 58/300
# 1/1 - 0s - loss: 0.5592 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 59/300
# 1/1 - 0s - loss: 0.5570 - binary_accuracy: 0.7500 - 1ms/epoch - 1ms/step
# Epoch 60/300
# 1/1 - 0s - loss: 0.5549 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 61/300
# 1/1 - 0s - loss: 0.5527 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 62/300
# 1/1 - 0s - loss: 0.5505 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 63/300
# 1/1 - 0s - loss: 0.5484 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 64/300
# 1/1 - 0s - loss: 0.5463 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 65/300
# 1/1 - 0s - loss: 0.5441 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 66/300
# 1/1 - 0s - loss: 0.5421 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 67/300
# 1/1 - 0s - loss: 0.5399 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 68/300
# 1/1 - 0s - loss: 0.5377 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 69/300
# 1/1 - 0s - loss: 0.5356 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 70/300
# 1/1 - 0s - loss: 0.5334 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 71/300
# 1/1 - 0s - loss: 0.5313 - binary_accuracy: 0.7500 - 4ms/epoch - 4ms/step
# Epoch 72/300
# 1/1 - 0s - loss: 0.5291 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 73/300
# 1/1 - 0s - loss: 0.5268 - binary_accuracy: 0.7500 - 4ms/epoch - 4ms/step
# Epoch 74/300
# 1/1 - 0s - loss: 0.5247 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 75/300
# 1/1 - 0s - loss: 0.5224 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 76/300
# 1/1 - 0s - loss: 0.5202 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 77/300
# 1/1 - 0s - loss: 0.5181 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 78/300
# 1/1 - 0s - loss: 0.5160 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 79/300
# 1/1 - 0s - loss: 0.5137 - binary_accuracy: 0.7500 - 4ms/epoch - 4ms/step
# Epoch 80/300
# 1/1 - 0s - loss: 0.5115 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 81/300
# 1/1 - 0s - loss: 0.5093 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 82/300
# 1/1 - 0s - loss: 0.5070 - binary_accuracy: 0.7500 - 4ms/epoch - 4ms/step
# Epoch 83/300
# 1/1 - 0s - loss: 0.5047 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 84/300
# 1/1 - 0s - loss: 0.5025 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 85/300
# 1/1 - 0s - loss: 0.5002 - binary_accuracy: 0.7500 - 6ms/epoch - 6ms/step
# Epoch 86/300
# 1/1 - 0s - loss: 0.4980 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 87/300
# 1/1 - 0s - loss: 0.4958 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 88/300
# 1/1 - 0s - loss: 0.4936 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 89/300
# 1/1 - 0s - loss: 0.4914 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 90/300
# 1/1 - 0s - loss: 0.4891 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 91/300
# 1/1 - 0s - loss: 0.4869 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 92/300
# 1/1 - 0s - loss: 0.4846 - binary_accuracy: 0.7500 - 8ms/epoch - 8ms/step
# Epoch 93/300
# 1/1 - 0s - loss: 0.4823 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 94/300
# 1/1 - 0s - loss: 0.4801 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 95/300
# 1/1 - 0s - loss: 0.4778 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 96/300
# 1/1 - 0s - loss: 0.4756 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 97/300
# 1/1 - 0s - loss: 0.4734 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 98/300
# 1/1 - 0s - loss: 0.4711 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 99/300
# 1/1 - 0s - loss: 0.4688 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 100/300
# 1/1 - 0s - loss: 0.4666 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 101/300
# 1/1 - 0s - loss: 0.4643 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 102/300
- binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 265/300
# 1/1 - 0s - loss: 0.1317 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 266/300
# 1/1 - 0s - loss: 0.1302 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 267/300
# 1/1 - 0s - loss: 0.1287 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 268/300
# 1/1 - 0s - loss: 0.1272 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 269/300
# 1/1 - 0s - loss: 0.1258 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 270/300
# 1/1 - 0s - loss: 0.1244 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 271/300
# 1/1 - 0s - loss: 0.1229 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 272/300
# 1/1 - 0s - loss: 0.1216 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 273/300
# 1/1 - 0s - loss: 0.1202 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 274/300
# 1/1 - 0s - loss: 0.1187 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 275/300
# 1/1 - 0s - loss: 0.1173 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 276/300
# 1/1 - 0s - loss: 0.1160 - binary_accuracy: 1.0000 - 8ms/epoch - 8ms/step
# Epoch 277/300
# 1/1 - 0s - loss: 0.1147 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 278/300
# 1/1 - 0s - loss: 0.1134 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 279/300
# 1/1 - 0s - loss: 0.1121 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 280/300
# 1/1 - 0s - loss: 0.1108 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 281/300
# 1/1 - 0s - loss: 0.1095 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 282/300
# 1/1 - 0s - loss: 0.1082 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 283/300
# 1/1 - 0s - loss: 0.1070 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 284/300
# 1/1 - 0s - loss: 0.1057 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 285/300
# 1/1 - 0s - loss: 0.1045 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 286/300
# 1/1 - 0s - loss: 0.1033 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 287/300
# 1/1 - 0s - loss: 0.1021 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 288/300
# 1/1 - 0s - loss: 0.1009 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 289/300
# 1/1 - 0s - loss: 0.0997 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 290/300
# 1/1 - 0s - loss: 0.0986 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 291/300
# 1/1 - 0s - loss: 0.0975 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 292/300
# 1/1 - 0s - loss: 0.0963 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 293/300
# 1/1 - 0s - loss: 0.0952 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 294/300
# 1/1 - 0s - loss: 0.0941 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 295/300
# 1/1 - 0s - loss: 0.0930 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 296/300
# 1/1 - 0s - loss: 0.0919 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 297/300
# 1/1 - 0s - loss: 0.0909 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 298/300
# 1/1 - 0s - loss: 0.0898 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 299/300
# 1/1 - 0s - loss: 0.0888 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 300/300
# 1/1 - 0s - loss: 0.0878 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step

# %%
# 5. 학습과정 살펴보기
hist.history.keys()
# Out:
# dict_keys(['loss', 'binary_accuracy'])

# %%
fig, loss_ax = plt.subplots(figsize=(10,5))
loss_ax.plot(hist.history['loss'], 'b', label='loss')
acc_ax = loss_ax.twinx() # loss_ax와 x축을 공유하는 acc_ax
acc_ax.plot(hist.history['binary_accuracy'], 'r', label='binary_accuracy')
loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('binary_accuracy')
loss_ax.legend(loc='center right')
acc_ax.legend(loc='center left')
plt.show()

# %%
# 모델 평가하기
score = model.evaluate(x_data, y_data) # loss & metrics(binary accuracy)
print('loss :', score[0])
print('accuracy :', score[1])
# Out:
# 1/1 [==============================] - 0s 128ms/step - loss: 0.0868 - binary_accuracy: 1.0000
# loss : 0.08676759153604507
# accuracy : 1.0

# %%
# 예측하기
model.predict(np.array([[0,1]]))
# Out:
# 1/1 [==============================] - 0s 98ms/step
# array([[0.9863829]], dtype=float32)
